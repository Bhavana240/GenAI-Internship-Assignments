# %%
# ==============================
# 📌 IMPORT LIBRARIES
# ==============================
import re
import string
from collections import Counter

# ==============================
# 📌 TASK 1: CONCEPTUAL ANSWERS
# ==============================

print("TASK 1: CONCEPTUAL ANSWERS\n")

print("1. Difference between 'Love' and 'love' in NLP:")
print("-> NLP treats them as different tokens unless converted to lowercase.\n")

print("2. What happens if stopwords are not removed?")
print("-> Model gets noisy data, reduces performance, increases computation.\n")

print("3. When removing stopwords is harmful:")
print("-> Sentiment analysis (e.g., 'not good')")
print("-> Question answering (e.g., 'what is your name')\n")

print("4. Stemming vs Lemmatization:")
print("-> Stemming: Cuts words (running → run)")
print("-> Lemmatization: Uses dictionary (better meaning)\n")

# ==============================
# 📌 TASK 2: PREPROCESS FUNCTION
# ==============================

def preprocess_text(text):
    try:
        # Handle empty input
        if not text or text.strip() == "":
            return [], ""

        # Convert to lowercase
        text = text.lower()

        # Remove URLs
        text = re.sub(r"http\S+|www\S+", "", text)

        # Remove emails
        text = re.sub(r"\S+@\S+", "", text)

        # Remove numbers
        text = re.sub(r"\d+", "", text)

        # Remove emojis (basic)
        text = re.sub(r"[^\w\s]", " ", text)

        # Handle repeated characters (soooo → soo)
        text = re.sub(r'(.)\1{2,}', r'\1\1', text)

        # Remove extra spaces
        text = re.sub(r"\s+", " ", text).strip()

        # Tokenization
        tokens = text.split()

        # Remove short words (<=2) except 'no', 'not'
        cleaned_tokens = []
        for word in tokens:
            if len(word) > 2 or word in ['no', 'not']:
                cleaned_tokens.append(word)

        # Final cleaned sentence
        cleaned_sentence = " ".join(cleaned_tokens)

        return cleaned_tokens, cleaned_sentence

    except Exception as e:
        print("Error:", e)
        return [], ""

# ==============================
# 📌 TASK 3: STRESS TESTING
# ==============================

test_sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

print("\nTASK 3: STRESS TESTING\n")

all_tokens = []

results = []

for sentence in test_sentences:
    tokens, clean_sentence = preprocess_text(sentence)

    print("Original:", sentence)
    print("Tokens:", tokens)
    print("Clean Sentence:", clean_sentence)
    print("-" * 50)

    all_tokens.extend(tokens)

    results.append({
        "original": sentence,
        "tokens": tokens,
        "clean": clean_sentence
    })

# ==============================
# 📌 TASK 4: TOKEN ANALYTICS
# ==============================

print("\nTASK 4: TOKEN ANALYTICS\n")

max_noise = ""
max_tokens = 0

for r in results:
    tokens = r["tokens"]

    if len(tokens) == 0:
        avg_len = 0
    else:
        avg_len = sum(len(w) for w in tokens) / len(tokens)

    print("Sentence:", r["original"])
    print("Total Tokens:", len(tokens))
    print("Unique Tokens:", len(set(tokens)))
    print("Avg Token Length:", round(avg_len, 2))
    print("-" * 40)

    # Most meaningful sentence
    if len(tokens) > max_tokens:
        max_tokens = len(tokens)
        max_noise = r["original"]

print("\nSentence with most meaningful tokens:", max_noise)

# ==============================
# 📌 TASK 5: FREQUENCY ANALYSIS
# ==============================

print("\nTASK 5: FREQUENCY ANALYSIS\n")

counter = Counter(all_tokens)

print("Top 10 Most Frequent Words:")
print(counter.most_common(10))

print("\nTop 5 Least Frequent Words:")
print(counter.most_common()[:-6:-1])

# ==============================
# 📌 TASK 6: FULL PIPELINE
# ==============================

def full_pipeline(text_list):
    all_tokens = []
    clean_sentences = []

    for text in text_list:
        tokens, clean = preprocess_text(text)
        all_tokens.extend(tokens)
        clean_sentences.append(clean)

    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }

# Run pipeline
pipeline_output = full_pipeline(test_sentences)

print("\nTASK 6: FULL PIPELINE OUTPUT\n")
print(pipeline_output)

# ==============================
# 📌 TASK 7: ERROR HANDLING TEST
# ==============================

print("\nTASK 7: ERROR HANDLING\n")

edge_cases = [
    "",
    "😂😂😂😂😂",
    "1234567890"
]

for case in edge_cases:
    tokens, clean = preprocess_text(case)
    print("Input:", case)
    print("Tokens:", tokens)
    print("Clean:", clean)
    print("-" * 40)
# Out:
# TASK 1: CONCEPTUAL ANSWERS
#
# 1. Difference between 'Love' and 'love' in NLP:
# -> NLP treats them as different tokens unless converted to lowercase.
#
# 2. What happens if stopwords are not removed?
# -> Model gets noisy data, reduces performance, increases computation.
#
# 3. When removing stopwords is harmful:
# -> Sentiment analysis (e.g., 'not good')
# -> Question answering (e.g., 'what is your name')
#
# 4. Stemming vs Lemmatization:
# -> Stemming: Cuts words (running → run)
# -> Lemmatization: Uses dictionary (better meaning)
#
#
# TASK 3: STRESS TESTING
#
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Clean Sentence: get free access now
# --------------------------------------------------
# Original: I absolutely looooved this product 😍😍
# Tokens: ['absolutely', 'looved', 'this', 'product']
# Clean Sentence: absolutely looved this product
# --------------------------------------------------
# Original: Worst service ever... 0/10
# ...
